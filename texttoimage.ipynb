# %%
 ! pip install min-dalle -q

# %%
from min_dalle import MinDalle

model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# intializing TextTokenizer
# initializing DalleBartEncoder
# initializing DalleBartDecoder
# initializing VQGanDetokenizer

# %%
text = "robots in paris at sunset"

seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# %%time

text = "mangoes under ocean"
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 31.3 s, sys: 267 ms, total: 31.6 s
# Wall time: 31.6 s

# %%
# %%time

text = "snake in a volcano"
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 31.5 s, sys: 350 ms, total: 31.9 s
# Wall time: 32.3 s

# %%
# %%time

text = "man fighting in wrestling"
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 30.3 s, sys: 212 ms, total: 30.5 s
# Wall time: 30.8 s

# %%
# %%time

text = "octopus in a desert"
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 31.3 s, sys: 301 ms, total: 31.6 s
# Wall time: 31.7 s
